# %%
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd
# Out:
# C:\Users\TranTung\Anaconda3\envs\py27\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
 cd C:\Users\TranTung\Desktop\DuLieu
# Out:
# C:\Users\TranTung\Desktop\DuLieu

# %%
pwd
# Out:
# u'C:\\Users\\TranTung\\Desktop\\DuLieu'

# %%
pd.read_csv('Data_DLSX_SimpleLinear.csv')
# Out:
#            Nam  Tong Dien Tich (NghinHa)  Dien Tich Lua (Nghin ha )  \
# 0         1990                    6476.9                     6042.8
# 1         1991                    6752.7                     6302.8
# 2         1992                    6956.3                     6475.3
# 3         1993                    7058.3                     6559.4
# 4         1994                    7135.7                     6598.6
# 5         1995                    7324.3                     6765.6
# 6         1996                    7620.6                     7003.8
# 7         1997                    7768.2                     7099.7
# 8         1998                    8016.0                     7362.7
# 9         1999                    8348.6                     7653.6
# 10        2000                    8399.1                     7666.3
# 11        2001                    8224.7                     7492.7
# 12        2002                    8322.5                     7504.3
# ...

# %%
x=pd.read_csv('Data_DLSX_SimpleLinear.csv')
x.head()
# Out:
#     Nam  Tong Dien Tich (NghinHa)  Dien Tich Lua (Nghin ha )  \
# 0  1990                    6476.9                     6042.8
# 1  1991                    6752.7                     6302.8
# 2  1992                    6956.3                     6475.3
# 3  1993                    7058.3                     6559.4
# 4  1994                    7135.7                     6598.6
#
#    Dien Tich Ng� (Ngh�n ha )  Tong San Luong(Nghin tan)  \
# 0                      431.8                    19897.7
# 1                      447.6                    20295.8
# 2                      478.0                    22342.8
# 3                      496.5                    23720.5
# 4                      534.6                    24673.7
#
#    San Luong Lua (Nghin Tan)  San Luong Ngo (Nghin Tan)
# 0                    19225.1                      671.0
# 1                    19621.9                      672.0
# 2                    21590.4                      747.9
# ...

# %%
cyl=x['Tong Dien Tich (NghinHa)']

# %%
cyl
# Out:
# 0     6476.9
# 1     6752.7
# 2     6956.3
# 3     7058.3
# 4     7135.7
# 5     7324.3
# 6     7620.6
# 7     7768.2
# 8     8016.0
# 9     8348.6
# 10    8399.1
# 11    8224.7
# 12    8322.5
# 13    8366.7
# 14    8437.8
# 15    8383.4
# 16    8359.7
# 17    8304.7
# 18    8542.2
# 19    8527.4
# 20    8615.9
# 21    8777.6
# 22    8918.9
# 23    9074.0
# 24    8996.2
# 25    8996.3
# 26    8947.9
# Name: Tong Dien Tich (NghinHa), dtype: float64

# %%
import statsmodels.api as sm # import statsmodels 

X = x["Tong Dien Tich (NghinHa)"] ## X usually means our input variables (or independent variables)
y = x["Tong San Luong(Nghin tan)"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model

# Note the difference in argument order
model = sm.OLS(y, X).fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# ...
# Dep. Variable:     Tong San Luong(Nghin tan)   R-squared:                       0.927
# Model:                                   OLS   Adj. R-squared:                  0.924
# Method:                        Least Squares   F-statistic:                     317.2
# Date:                       Mon, 09 Jul 2018   Prob (F-statistic):           1.02e-15
# Time:                               20:30:26   Log-Likelihood:                -250.59
# No. Observations:                         27   AIC:                             505.2
# Df Residuals:                             25   BIC:                             507.8
# Df Model:                                  1
# Covariance Type:                   nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# ...
